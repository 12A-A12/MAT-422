# %% [markdown]
# <a href="https://colab.research.google.com/github/12A-A12/MAT-422/blob/MAT-422-HW/MAT422_4_2_Spectral_Graph_Bipartitioning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 4.2 Spectral Graph Bipartioning

# %% [markdown]
# There are various concepts which will be explored in the following examples which all provide insight into the various processes and concepts pertaining to Linear Algebra with a focus primarily on the main elements which are as follows:
# - Spectral Graph Bipartioning
#
# The concept of Spectral Graph Bipartioning is an especially important mathematical concepts in Network Analysis and node creation. Graph Bipartioning provides the ability to make network analysis more effective and is useful in providing methodology to solving this. Along with this, it makes looking at graphical data, analysing it, and breaking it down more effective. This process is essential for data analysis.
#
# Note: Example problems generated by author

# %% [markdown]
# # Spectral Graph Bipartioning
#
# The process of spectral graph bipartioning is the process in which a partition within the graph is made in an effort to find the cut or edges that are in between the area that exists between two disjointed node sets in order to minimize and make the data and information more acccurate.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
random.seed(1)
x, _ = make_blobs(n_samples=400, centers=4, cluster_std=1.5)

plt.scatter(x[:, 0], x[:, 1])
plt.show()

clustering = SpectralClustering(affinity='rbf', assign_labels='kmeans', coef0=1, degree=3,eigen_tol=0.0, gamma=1.0, n_clusters=4,n_init=10, n_neighbors=10)

# %%
G = nx.Graph()
G.add_weighted_edges_from([(1, 2, 7), (1, 3, 9), (1, 6, 14), (2, 3, 10), (2, 4, 15),(3, 4, 11), (3, 6, 2), (4, 5, 6), (5, 6, 9)])

pos = nx.spring_layout(G)

nx.draw(G, pos, with_labels=True)
plt.show()

# %% [markdown]
# References:
#
# 1. Ren, Jingli, and Haiyan Wang. Mathematical Methods in Data Science. Elsevier, 2023.
