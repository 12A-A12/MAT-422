# %% [markdown]
# <a href="https://colab.research.google.com/github/12A-A12/MAT-422/blob/MAT-422-HW/MAT422_3_5_%26_3_6_K_means_and_Support_Vector_Machines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 3.5 & 3.6 K-Means and Support Vector Machine (SVM)

# %% [markdown]
# There are various concepts which will be explored in the following examples which all provide insight into the various processes and concepts pertaining to Linear Algebra with a focus primarily on the main elements which are as follows:
# - K-Means
# - Suppport Vector Machine (SVM)
#
# The process of K-Means is a method of clustering in which vector quantization is done in order togenerate observations and determines convergence, distances, and various other values in reference to obtained data. It is an essential aspect of data analysis. Another essential methodw which is commonly used are Support Vector Machines (SVM), which  are learning models in machine learning in which data can be analyzed and classifiedd according to a regression analysis of said data. These two processes are essential for data analysis
#
# Note: Example problems generated by author

# %% [markdown]
# # K-Means
#
# K-Means, as previously mentioned, is an important process, and is a method of clustering in which vector quantization is done in order to generate observations and determine convergences. Along with this, this data can be used to determine convergence of points, distances between pointss, and various other values where the data can be clustered and observed. This is an important technique which is used for data analysis and explanation.
#
# ![image.png](data:image/png;base64,...)

# %%
X, y_true = make_blobs(n_samples = 500, centers = 10, cluster_std = 0.75, random_state = 0)
plt.scatter(X[:, 0], X[:, 1])

Result = KMeans(n_clusters = 4,n_init = 25)
Result.fit(X)
Resulty = Result.predict(X)
plt.scatter(X[:, 0], X[:, 1], c = Resulty, s = 75)

centers = Result.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c = 'black', s = 301, alpha = 0.65)

# %%
wcss = []

for i in range(1, 15):
  Result = KMeans(n_clusters = i, init = 'k-means++', max_iter = 500, n_init = 25, random_state = 0)
  Result.fit(X)
  wcss.append(Result.inertia_)
plt.plot(range(1, 15), wcss)
plt.title('K-Mean')
plt.show()

# %% [markdown]
# The example above showcases two examples in which K-mean can be observed, one of which provides an example of scatterplots and the center of this data. Another provides a regression curve which showcases the K-mean.

# %% [markdown]
# # Support Vector Machines
#
# An essential method which is commonly used are Support Vector Machines (SVM), which  are learning models in machine learning in which data can be analyzed and classifiedd according to a regression analysis of said data. Using this method, the data can be regressed, seperated into different classifications, and can be trained. When training SVM, a model is built by assigning examples to a category in which this model then reads and learns from this example and uses it for analysis. This process is incredibly essential for data analysis.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
    for i in range(n_samples):
            for j in range(n_samples):
                K[i,j] = np.dot(X[i], X[j])

plt.scatter(X[:, 0], X[:, 1], c = y)

# %%
def generate_dataset(size):
    x, y, target = [], [], []
    for i in range(size):
        x.extend([round(random.uniform(1, 3.5), 1), round(random.uniform(0.5, 4.5), 2), round(random.uniform(2, 4.5), 2)])
        y.extend([round(random.uniform(0, 25), 1), round(random.uniform(15, 30), 2), round(random.uniform(8, 28), 2)])
        target.extend([0, 1, 1])
    data_frame = pd.DataFrame({'x': x, 'y': y, 'target': target})
    return data_frame

fig, ax = plt.subplots(figsize=(14, 8))
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
ax.scatter(features[:-test_size]['x'], features[:-test_size]['y'], color="#8C7298")
plt.show()

fig, ax = plt.subplots(figsize=(14, 8))
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

xx = np.linspace(-1, max(features['x']) + 2, len(x_train))
yy = np.linspace(-1, max(features['y']) + 3, len(y_train))
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T

ax.scatter(features[:-test_size]['x'], features[:-test_size]['y'])

Z = model.decision_function(xy).reshape(XX.shape)
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])
ax.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1], s=120, linewidth=1, facecolors='none', edgecolors='k')
plt.show()

predictions_rbf = model.predict(x_test)
accuracy_rbf = accuracy_score(y_test, predictions_rbf)
print(f"RBF Kernel\nAccuracy (normalized): {accuracy_rbf}")
# Out:
# RBF Kernel
# Accuracy (normalized): 0.7333333333333333

# %% [markdown]
# The examples above shows two examples, one of which shows a linear scatterplot in which data is spread as well as a use of another scatterplot which then used SVM to find centering data and coveed areas within these scatterplot areas.

# %% [markdown]
# References:
#
# 1. Ren, Jingli, and Haiyan Wang. Mathematical Methods in Data Science. Elsevier, 2023.
