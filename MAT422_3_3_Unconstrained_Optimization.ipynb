# %% [markdown]
# <a href="https://colab.research.google.com/github/12A-A12/MAT-422/blob/MAT-422-HW/MAT422_3_3_Unconstrained_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3.2 Unconstrained Optimization

# %% [markdown]
# There are various concepts which will be explored in the following examples which all provide insight into the various processes and concepts pertaining to Linear Algebra with a focus primarily on the main elements which are as follows:
# - Necessary and sufficient conditions of local minimizers
# - Convexity and Global Minimizers
# - Gradient Descent
#
# The process of unconstrained optimizations is an incredibly useful concept for deriving. These derivations are specifically for determining optimality conditions in reference to continous functions which need to be optimized. The processes typically used in these include processes such as minimizers, convexxity, and gradients.
#
# Note: Example problems generated by author

# %% [markdown]
# # Necessary and Sufficient Conditions of Local Minimizers
#
# When working with unconstrained optimizations of a particular form, given a particular subsection, several solutions and characterizations can be derived. In doing so, a global minimizer can be found for optimizing.
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

x = np.arange(0, 5, 0.001)
function = np.sin(3*np.pi*x)- np.sin(5*np.pi) * np.sin(2*np.pi*5*x)

minimumx = x[np.argmin(function)]
minimumy = np.min(function)

plt.title("Minima's")

plt.plot(x, function)


plt.plot(minimumx, minimumy, 'ro')

plt.show()

# %% [markdown]
# The example above shows an example of minimum and maximum as well as how exactly conditions of local minimization and minimizers can be used in order to conduct optimizations.

# %% [markdown]
# # Convexity and Global Minimizers
#
# When dealing with functions, convex's and the process of convexity can be used within line segments to determine particular data points. The line segment between two points on a given function can be described as a convex, and in order to optimize, there is a certain amount of local minimizers. This local minimas can be used to determine gradients and used for other relevant topics.
#
# ![image.png](data:image/png;base64,...)

# %%
def convex_function(x):
    return x**5

x = np.linspace(-10, 10, 1000)

y = convex_function(x)

plt.plot(x, y)

minimumx = x[np.argmin(function)]
minimumy = np.min(function)
plt.plot(minimumx, minimumy, 'ro', label='Global Minimizer (0, 0)')

plt.axhline(y=0, color='red', linestyle='--', label='Red Line')


plt.title('Convex Function and Global Minimizer')


plt.show()

# %% [markdown]
# The above example shows an example of how convexity and global minimizers are used in the optimization process.

# %% [markdown]
# # Gradient Descent
#
# Gradient descent can be used as an iterative process in which optimization is conducted for a function in order to determine a minimizer. In this the function can have a gradient created through derivaatives which will show a descent of some kind in the system
#
# ![image.png](data:image/png;base64,...)

# %%
x = np.linspace(-10,10,2000)
y = x ** 5 + 6

plt.plot(x,y)
plt.show()

# %% [markdown]
# The example above shows an example of gradient descent in which the gradient increasingly decreases or changes in order to determine minimas.

# %% [markdown]
# References:
#
# 1. Ren, Jingli, and Haiyan Wang. Mathematical Methods in Data Science. Elsevier, 2023.
