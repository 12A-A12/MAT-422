# %% [markdown]
# <a href="https://colab.research.google.com/github/12A-A12/MAT-422/blob/MAT-422-HW/MAT422_3_4_Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 3.4 Logistic Regression

# %% [markdown]
# There are various concepts which will be explored in the following examples which all provide insight into the various processes and concepts pertaining to Linear Algebra with a focus primarily on the main elements which are as follows:
# - Logistic Regression
#
# The process of Logistic Regression is an incredibly useful model in which a logistic function is utilized to create a dependent variable with a binary. These derivations are specifically for determining optimality conditions in reference to continous functions which need to be optimized. The processes typically used in these include processes such as minimizers, convexity, and gradients.
#
# Note: Example problems generated by author

# %% [markdown]
# # Logistic Regression
#
# While linear regression is a useful and commonly used methodology for determining linear functions and other related topics. Logistic regression is a similar methodology, however it is used for logistic functions, specifically to create dependent variables that are binary. Using this, it can be used to create predictive models and classifications as well as being used to determine gradient descents as well as a multitude of other values as well. Along with this, it can be useful for determining probabilities and other related topics.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
x = np.random.rand(100, 2)
y = (X[:, 0] + X[:, 1] > 1).astype(int)
xt,xxt,yt,yyt = train_test_split(x, y, test_size=0.2, random_state=42)

model.fit(xt, yt)

predict = model.predict(xxt)

accuracy = accuracy_score(yyt, predict)
print(accuracy)

report = classification_report(yyt, predict)
print(report)

fig, ax = plt.subplots(figsize=(8, 8))
ax.imshow(cm)
ax.grid(False)
ax.xaxis.set(ticks=(0, 1), ticklabels=('Predicted 0s', 'Predicted 1s'))
ax.yaxis.set(ticks=(0, 1), ticklabels=('Actual 0s', 'Actual 1s'))
ax.set_ylim(1.5, -0.5)
for i in range(2):
    for j in range(2):
        ax.text(j, i, cm[i, j], ha='center', va='center', color='red')
plt.show()
# Out:
# 0.45
#               precision    recall  f1-score   support
#
#            0       0.44      0.40      0.42        10
#            1       0.45      0.50      0.48        10
#
#     accuracy                           0.45        20
#    macro avg       0.45      0.45      0.45        20
# weighted avg       0.45      0.45      0.45        20

# %%
x = np.arange(-100, 100, 0.0001)
y = sigmoid(x)

plt.title('Sigmoid')
plt.plot(x, y)
plt.show()

# %% [markdown]
# The examples above showcases an example of logistic regression in which a regression table is shown indicating values such as precision, f1-score, accuracy, and various other factor. Along with this, there is a matrix table in which there are tables which indicates the actual and predicted values of 1's and 0's. Along with this, the sigmoid function is also plotted.

# %% [markdown]
# References:
#
# 1. Ren, Jingli, and Haiyan Wang. Mathematical Methods in Data Science. Elsevier, 2023.
